# %%
d = {"key1":"value1", "key2":"value2"}

# %%
d["key1"]
# Out:
# 'value1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key1":"value1", "key2":"value2"})

# %%
d2
# Out:
# ConfigBox({'key1': 'value1', 'key2': 'value2'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(2, 4)
# Out:
# 8

# %%
get_prodict(2, "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(2, 4)
# Out:
# 8

# %%
get_prodict(2, "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 get_prodict(2, "4")
#
# File e:\Personal\SmartEEDigital\Study\MLOps\E2E-Machine-Learning-Project-with-MLFlow\venv\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x000001CB9F561A60> does not match annotation type <class 'int'>
